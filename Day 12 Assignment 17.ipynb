# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.width',5000)
customers = pd.read_csv('D:\\RIYA\\college stuff\\ML with python\\FyntraCustomerData.csv')
customers
# Out:
#                              Email                                            Address            Avatar  Avg_Session_Length  Time_on_App  Time_on_Website  Length_of_Membership  Yearly_Amount_Spent
# 0        mstephenson@fernandez.com       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet           34.497268    12.655651        39.577668              4.082621           587.951054
# 1                hduke@hotmail.com     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen           31.926272    11.109461        37.268959              2.664034           392.204933
# 2                 pallen@yahoo.com  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque           33.000915    11.330278        37.110597              4.104543           487.547505
# 3          riverarebecca@gmail.com   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown           34.305557    13.717514        36.721283              3.120179           581.852344
# ...

# %%
print(customers.info())
print('\n')
print(customers.describe())
print('\n')
print(customers.count())
print('\n')
print(customers.shape)
print('\n')
print(customers.groupby('Avatar').size())
print('\n')
print(customers.groupby('Avatar').count())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg_Session_Length    500 non-null    float64
#  4   Time_on_App           500 non-null    float64
#  5   Time_on_Website       500 non-null    float64
#  6   Length_of_Membership  500 non-null    float64
#  7   Yearly_Amount_Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB
# None
#
#
#        Avg_Session_Length  Time_on_App  Time_on_Website  Length_of_Membership  Yearly_Amount_Spent
# count          500.000000   500.000000       500.000000            500.000000           500.000000
# ...

# %%
print(customers.isnull().sum())
print('\n')
print(customers.notnull().sum())
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg_Session_Length      0
# Time_on_App             0
# Time_on_Website         0
# Length_of_Membership    0
# Yearly_Amount_Spent     0
# dtype: int64
#
#
# Email                   500
# Address                 500
# Avatar                  500
# Avg_Session_Length      500
# Time_on_App             500
# Time_on_Website         500
# Length_of_Membership    500
# Yearly_Amount_Spent     500
# dtype: int64

# %%
#no null values
#to compare time on website and yearly spent
sns.jointplot(x='Time_on_Website',y='Yearly_Amount_Spent',data=customers)

# %%
sns.set_palette('bright')
sns.set_style('whitegrid')
sns.jointplot(x='Time_on_Website',y='Yearly_Amount_Spent',data=customers)

# %%
#now to compare time on app and yearly spent 
sns.jointplot(x='Time_on_App',y='Yearly_Amount_Spent',data=customers)

# %%
#yearly spent money seems linearly increasing with time spent on app
#while yearly spent money seems scattered in between the plot
customers.corr()
# Out:
#                       Avg_Session_Length  Time_on_App  Time_on_Website  Length_of_Membership  Yearly_Amount_Spent
# Avg_Session_Length              1.000000    -0.027826        -0.034987              0.060247             0.355088
# Time_on_App                    -0.027826     1.000000         0.082388              0.029143             0.499328
# Time_on_Website                -0.034987     0.082388         1.000000             -0.047582            -0.002641
# Length_of_Membership            0.060247     0.029143        -0.047582              1.000000             0.809084
# Yearly_Amount_Spent             0.355088     0.499328        -0.002641              0.809084             1.000000

# %%
sns.pairplot(customers)

# %%
#so clearly length_of_mebership has realtion with yearly_amount_spent more than any other thing
sns.lmplot(x='Length_of_Membership',y='Yearly_Amount_Spent',data=customers)

# %%
x=customers[['Avg_Session_Length','Time_on_App','Time_on_Website',"Length_of_Membership"]]
print(x)
y = customers['Yearly_Amount_Spent']
print(y)
# Out:
#      Avg_Session_Length  Time_on_App  Time_on_Website  Length_of_Membership
# 0             34.497268    12.655651        39.577668              4.082621
# 1             31.926272    11.109461        37.268959              2.664034
# 2             33.000915    11.330278        37.110597              4.104543
# 3             34.305557    13.717514        36.721283              3.120179
# 4             33.330673    12.795189        37.536653              4.446308
# ..                  ...          ...              ...                   ...
# 495           33.237660    13.566160        36.417985              3.746573
# 496           34.702529    11.695736        37.190268              3.576526
# 497           32.646777    11.499409        38.332576              4.958264
# 498           33.322501    12.391423        36.840086              2.336485
# 499           33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]
# 0      587.951054
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=85)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(x_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('Coefficients:\n',lr.coef_)
print('Intercept:\n',lr.intercept_)
# Out:
# Coefficients:
#  [26.08163249 39.18778762  0.40460005 61.41777824]
# Intercept:
#  -1067.382427610522

# %%
from sklearn import metrics 
print('RMSE:\n', round(np.sqrt(metrics.mean_squared_error(y_test,predictions)),2))
# Out:
# RMSE:
#  10.57

# %%
sns.distplot((y_test,predictions),bins=50)
# Out:
# C:\Users\91988\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
coeffecients = pd.DataFrame(lr.coef_,x.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                       Coeffecient
# Avg_Session_Length      26.081632
# Time_on_App             39.187788
# Time_on_Website          0.404600
# Length_of_Membership    61.417778

# %%
#clearly more dependency on Length_of_Membership than any other features, second on which yearly spent depends is Time_on_App so 
#company should work more on app than on website
