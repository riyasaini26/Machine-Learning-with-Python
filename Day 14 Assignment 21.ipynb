# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import numpy as np
os.chdir('D:\\RIYA\\college stuff\\ML with python')
os.getcwd()
animals = pd.read_csv('horse.csv')
animals
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
df = animals
df
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
# ...

# %%
print(df.groupby('outcome').size())
print(df.dtypes)
# Out:
# outcome
# died           77
# euthanized     44
# lived         178
# dtype: int64
# surgery                   object
# age                       object
# hospital_number            int64
# rectal_temp              float64
# pulse                    float64
# respiratory_rate         float64
# temp_of_extremities       object
# peripheral_pulse          object
# mucous_membrane           object
# capillary_refill_time     object
# pain                      object
# peristalsis               object
# abdominal_distention      object
# nasogastric_tube          object
# nasogastric_reflux        object
# nasogastric_reflux_ph    float64
# rectal_exam_feces         object
# abdomen                   object
# packed_cell_volume       float64
# total_protein            float64
# abdomo_appearance         object
# abdomo_protein           float64
# outcome                   object
# surgical_lesion           object
# lesion_1                   int64
# lesion_2                   int64
# ...

# %%
columns = df.columns
print(columns)
# Out:
# Index(['surgery', 'age', 'hospital_number', 'rectal_temp', 'pulse',
#        'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse',
#        'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
#        'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
#        'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen',
#        'packed_cell_volume', 'total_protein', 'abdomo_appearance',
#        'abdomo_protein', 'outcome', 'surgical_lesion', 'lesion_1', 'lesion_2',
#        'lesion_3', 'cp_data'],
#       dtype='object')

# %%
target = df['outcome']
print(target)
# Out:
# 0            died
# 1      euthanized
# 2           lived
# 3            died
# 4            died
#           ...
# 294    euthanized
# 295    euthanized
# 296          died
# 297         lived
# 298    euthanized
# Name: outcome, Length: 299, dtype: object

# %%
target.unique()
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
df = df.drop(['outcome'],axis=1)
print(df)
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
dtype_null = pd.concat([df.isnull().sum(),df.dtypes],axis=1)
dtype_null.columns = ['Null_Count','Datatype']
dtype_null
# Out:
#                        Null_Count Datatype
# surgery                         0   object
# age                             0   object
# hospital_number                 0    int64
# rectal_temp                    60  float64
# pulse                          24  float64
# respiratory_rate               58  float64
# temp_of_extremities            56   object
# peripheral_pulse               69   object
# mucous_membrane                47   object
# capillary_refill_time          32   object
# pain                           55   object
# peristalsis                    44   object
# abdominal_distention           56   object
# nasogastric_tube              104   object
# nasogastric_reflux            106   object
# nasogastric_reflux_ph         246  float64
# rectal_exam_feces             102   object
# abdomen                       118   object
# packed_cell_volume             29  float64
# total_protein                  33  float64
# abdomo_appearance             165   object
# ...

# %%
category_cols = dtype_null[(dtype_null.Null_Count>0)&(dtype_null.Datatype=='object')]
category_cols
# Out:
#                        Null_Count Datatype
# temp_of_extremities            56   object
# peripheral_pulse               69   object
# mucous_membrane                47   object
# capillary_refill_time          32   object
# pain                           55   object
# peristalsis                    44   object
# abdominal_distention           56   object
# nasogastric_tube              104   object
# nasogastric_reflux            106   object
# rectal_exam_feces             102   object
# abdomen                       118   object
# abdomo_appearance             165   object

# %%
category_variables = list(category_cols.index)
category_variables
# Out:
# ['temp_of_extremities',
#  'peripheral_pulse',
#  'mucous_membrane',
#  'capillary_refill_time',
#  'pain',
#  'peristalsis',
#  'abdominal_distention',
#  'nasogastric_tube',
#  'nasogastric_reflux',
#  'rectal_exam_feces',
#  'abdomen',
#  'abdomo_appearance']

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
df[category_variables]=imp.fit_transform(df[category_variables])
df
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
dtype_null = pd.concat([df.isnull().sum(),df.dtypes],axis=1)
dtype_null.columns = ['Null_Count','Datatype']
dtype_null
# Out:
#                        Null_Count Datatype
# surgery                         0   object
# age                             0   object
# hospital_number                 0    int64
# rectal_temp                    60  float64
# pulse                          24  float64
# respiratory_rate               58  float64
# temp_of_extremities             0   object
# peripheral_pulse                0   object
# mucous_membrane                 0   object
# capillary_refill_time           0   object
# pain                            0   object
# peristalsis                     0   object
# abdominal_distention            0   object
# nasogastric_tube                0   object
# nasogastric_reflux              0   object
# nasogastric_reflux_ph         246  float64
# rectal_exam_feces               0   object
# abdomen                         0   object
# packed_cell_volume             29  float64
# total_protein                  33  float64
# abdomo_appearance               0   object
# ...

# %%
df.to_excel('D:\\RIYA\\college stuff\\ML with python\\CS32.xlsx')
df
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
float_cols = dtype_null[(dtype_null.Null_Count>0)]
float_cols
# Out:
#                        Null_Count Datatype
# rectal_temp                    60  float64
# pulse                          24  float64
# respiratory_rate               58  float64
# nasogastric_reflux_ph         246  float64
# packed_cell_volume             29  float64
# total_protein                  33  float64
# abdomo_protein                198  float64

# %%
float_variables = list(float_cols.index)
float_variables
# Out:
# ['rectal_temp',
#  'pulse',
#  'respiratory_rate',
#  'nasogastric_reflux_ph',
#  'packed_cell_volume',
#  'total_protein',
#  'abdomo_protein']

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='mean')
df[float_variables]=imp.fit_transform(df[float_variables])
df.to_excel('D:\\RIYA\\college stuff\\ML with python\\CS32.xlsx')
df
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101    38.500000   66.0              28.0
# 1       yes  adult           534817    39.200000   88.0              20.0
# 2        no  adult           530334    38.300000   40.0              24.0
# 3       yes  young          5290409    39.100000  164.0              84.0
# 4        no  adult           530255    37.300000  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886    38.168619  120.0              70.0
# 295      no  adult           527702    37.200000   72.0              24.0
# 296     yes  adult           529386    37.500000   72.0              30.0
# 297     yes  adult           530612    36.500000  100.0              24.0
# 298     yes  adult           534618    37.200000   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
df[float_variables]
# Out:
#      rectal_temp  pulse  respiratory_rate  nasogastric_reflux_ph  \
# 0      38.500000   66.0              28.0               4.707547
# 1      39.200000   88.0              20.0               4.707547
# 2      38.300000   40.0              24.0               4.707547
# 3      39.100000  164.0              84.0               5.000000
# 4      37.300000  104.0              35.0               4.707547
# ..           ...    ...               ...                    ...
# 294    38.168619  120.0              70.0               4.707547
# 295    37.200000   72.0              24.0               4.707547
# 296    37.500000   72.0              30.0               4.707547
# 297    36.500000  100.0              24.0               4.707547
# 298    37.200000   40.0              20.0               4.707547
#
#      packed_cell_volume  total_protein  abdomo_protein
# 0                  45.0       8.400000        3.039604
# 1                  50.0      85.000000        2.000000
# ...

# %%
df
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101    38.500000   66.0              28.0
# 1       yes  adult           534817    39.200000   88.0              20.0
# 2        no  adult           530334    38.300000   40.0              24.0
# 3       yes  young          5290409    39.100000  164.0              84.0
# 4        no  adult           530255    37.300000  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886    38.168619  120.0              70.0
# 295      no  adult           527702    37.200000   72.0              24.0
# 296     yes  adult           529386    37.500000   72.0              30.0
# 297     yes  adult           530612    36.500000  100.0              24.0
# 298     yes  adult           534618    37.200000   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
allcategory_cols = dtype_null[dtype_null.Datatype=='object']
allcategory_cols = list(allcategory_cols.index)
allcategory_cols
# Out:
# ['surgery',
#  'age',
#  'temp_of_extremities',
#  'peripheral_pulse',
#  'mucous_membrane',
#  'capillary_refill_time',
#  'pain',
#  'peristalsis',
#  'abdominal_distention',
#  'nasogastric_tube',
#  'nasogastric_reflux',
#  'rectal_exam_feces',
#  'abdomen',
#  'abdomo_appearance',
#  'surgical_lesion',
#  'cp_data']

# %%
df1=df
for i in allcategory_cols:
    df1 = pd.get_dummies(df1,columns=[i],drop_first=True)
df1.to_excel('D:\\RIYA\\college stuff\\ML with python\\CS32onehot.xlsx')
df1
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0             530101    38.500000   66.0              28.0
# 1             534817    39.200000   88.0              20.0
# 2             530334    38.300000   40.0              24.0
# 3            5290409    39.100000  164.0              84.0
# 4             530255    37.300000  104.0              35.0
# ..               ...          ...    ...               ...
# 294           533886    38.168619  120.0              70.0
# 295           527702    37.200000   72.0              24.0
# 296           529386    37.500000   72.0              30.0
# 297           530612    36.500000  100.0              24.0
# 298           534618    37.200000   40.0              20.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 0                 4.707547                45.0       8.400000        3.039604
# 1                 4.707547                50.0      85.000000        2.000000
# ...

# %%
target.unique()
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
target = label.fit_transform(target)
print(target)
# Out:
# [0 1 2 0 0 2 2 0 1 2 2 2 2 0 2 0 0 2 2 2 2 2 2 2 2 2 2 2 0 2 0 1 2 2 2 1 1
#  2 2 0 0 2 2 1 1 0 2 2 0 0 2 0 2 2 1 0 2 0 0 0 2 2 0 1 2 2 2 2 2 2 1 2 0 0
#  0 1 2 2 0 2 0 2 2 0 2 2 0 1 2 2 2 0 2 0 2 2 2 1 2 2 2 1 2 2 0 2 2 2 1 0 0
#  2 2 0 2 2 2 1 2 2 2 1 2 0 1 2 2 2 1 2 0 0 2 0 0 0 2 2 2 2 0 0 2 1 2 2 0 2
#  2 2 0 2 2 2 2 2 1 2 2 2 0 2 1 2 1 2 2 2 1 2 0 2 0 0 2 2 0 2 1 0 2 0 2 2 2
#  2 2 2 2 2 2 2 0 2 2 1 0 2 2 2 0 1 2 2 1 2 0 1 2 0 0 2 2 2 2 2 2 1 2 1 2 2
#  2 2 2 0 2 1 2 2 0 2 2 2 0 2 2 1 1 0 2 0 2 2 0 2 0 2 2 1 0 0 2 2 0 1 0 2 0
#  2 2 2 0 2 1 2 2 2 2 0 2 2 0 1 0 1 2 2 2 2 0 0 2 2 2 1 2 2 2 2 0 0 1 2 1 1
#  0 2 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1, target, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (239, 51)
# (60, 51)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ydt_pred = dt.predict(X_test)
ydt_pred
# Out:
# array([1, 2, 2, 1, 0, 2, 0, 1, 2, 2, 1, 2, 2, 1, 0, 1, 0, 0, 2, 2, 0, 2,
#        1, 0, 2, 2, 0, 1, 2, 1, 2, 0, 2, 1, 1, 0, 2, 2, 2, 2, 0, 2, 2, 1,
#        0, 1, 0, 0, 0, 2, 2, 2, 2, 1, 1, 2, 2, 2, 0, 2])

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(ydt_pred,y_test)
print(accuracy)
# Out:
# 0.6333333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
yrf_predict = rf.predict(X_test)
yrf_predict
# Out:
# array([1, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 0, 0, 2, 0, 2, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2])

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(yrf_predict,y_test)
print(accuracy)
# Out:
# 0.75
